# %%
#!conda install -c conda-forge faker -y
#!conda install -c conda-forge geopy -y
#!pip install pymysql
#!pip install psycopg2

# %%
import json, random
import pandas as pd
from time import time,sleep
from faker import Faker
from geopy import distance

# %%
faker = Faker()

# %% [markdown]
# # Generate data from faker

# %%
data_list = []
for i in range(50):
    data = dict(
        device_id=random.choice(['5390df32-b924-44e9-b416-eb31066741e4','f87141eb-feff-45b8-88a4-0550d58a14ac']),
        temperature=faker.random_int(10, 50),
        location=dict(latitude=str(faker.latitude()), longitude=str(faker.longitude())),
        time=str(int(time()))
    )
    sleep(0.5)
    data_list.append(data)

# %%
output = pd.DataFrame()
df_dictionary = pd.DataFrame(data_list)

# %%
data_list[0]
# Out:
# {'device_id': '5390df32-b924-44e9-b416-eb31066741e4',
#  'temperature': 34,
#  'location': {'latitude': '10.7800565', 'longitude': '125.855662'},
#  'time': '1693210784'}

# %%
df_dictionary = df_dictionary.sort_values(['device_id','time'], ascending = True)
df_dictionary
# Out:
#                                device_id  temperature  \
# 0   5390df32-b924-44e9-b416-eb31066741e4           34
# 1   5390df32-b924-44e9-b416-eb31066741e4           23
# 5   5390df32-b924-44e9-b416-eb31066741e4           33
# 7   5390df32-b924-44e9-b416-eb31066741e4           24
# 9   5390df32-b924-44e9-b416-eb31066741e4           10
# 10  5390df32-b924-44e9-b416-eb31066741e4           31
# 14  5390df32-b924-44e9-b416-eb31066741e4           45
# 18  5390df32-b924-44e9-b416-eb31066741e4           19
# 20  5390df32-b924-44e9-b416-eb31066741e4           14
# 22  5390df32-b924-44e9-b416-eb31066741e4           20
# 24  5390df32-b924-44e9-b416-eb31066741e4           23
# 25  5390df32-b924-44e9-b416-eb31066741e4           44
# 27  5390df32-b924-44e9-b416-eb31066741e4           50
# 28  5390df32-b924-44e9-b416-eb31066741e4           12
# 29  5390df32-b924-44e9-b416-eb31066741e4           50
# 31  5390df32-b924-44e9-b416-eb31066741e4           14
# 34  5390df32-b924-44e9-b416-eb31066741e4           21
# 35  5390df32-b924-44e9-b416-eb31066741e4           20
# 36  5390df32-b924-44e9-b416-eb31066741e4           17
# 40  5390df32-b924-44e9-b416-eb31066741e4           40
# 44  5390df32-b924-44e9-b416-eb31066741e4           48
# 46  5390df32-b924-44e9-b416-eb31066741e4           36
# 47  5390df32-b924-44e9-b416-eb31066741e4           42
# 49  5390df32-b924-44e9-b416-eb31066741e4           37
# 2   f87141eb-feff-45b8-88a4-0550d58a14ac           18
# 3   f87141eb-feff-45b8-88a4-0550d58a14ac           49
# 4   f87141eb-feff-45b8-88a4-0550d58a14ac           20
# 6   f87141eb-feff-45b8-88a4-0550d58a14ac           21
# 8   f87141eb-feff-45b8-88a4-0550d58a14ac           38
# 11  f87141eb-feff-45b8-88a4-0550d58a14ac           37
# 12  f87141eb-feff-45b8-88a4-0550d58a14ac           15
# 13  f87141eb-feff-45b8-88a4-0550d58a14ac           43
# 3   {'latitude': '64.1164715', 'longitude': '-10.3...  1693210786
# 4   {'latitude': '73.8800505', 'longitude': '-104....  1693210786
# 6   {'latitude': '68.502382', 'longitude': '177.70...  1693210787
# 8   {'latitude': '-57.2823875', 'longitude': '41.5...  1693210788
# 11  {'latitude': '-32.904390', 'longitude': '115.9...  1693210790
# 12  {'latitude': '8.3313785', 'longitude': '-175.9...  1693210790
# 13  {'latitude': '73.693304', 'longitude': '-1.058...  1693210791
# 15  {'latitude': '23.3508845', 'longitude': '-25.3...  1693210792
# 16  {'latitude': '-15.112969', 'longitude': '-22.1...  1693210792
# 17  {'latitude': '29.956552', 'longitude': '98.060...  1693210793
# 19  {'latitude': '57.2631085', 'longitude': '-54.1...  1693210794
# 21  {'latitude': '-26.652955', 'longitude': '-119....  1693210795
# 23  {'latitude': '68.9954395', 'longitude': '-87.2...  1693210796
# 26  {'latitude': '70.8020285', 'longitude': '-22.9...  1693210797
# 30  {'latitude': '5.7248575', 'longitude': '-62.41...  1693210799
# 32  {'latitude': '29.1181555', 'longitude': '-2.58...  1693210800
# 33  {'latitude': '72.0302635', 'longitude': '-45.1...  1693210801
# 37  {'latitude': '-28.8357565', 'longitude': '95.9...  1693210803
# 38  {'latitude': '26.727525', 'longitude': '135.53...  1693210803
# 39  {'latitude': '-9.6067815', 'longitude': '130.4...  1693210804
# 41  {'latitude': '-26.7759195', 'longitude': '-71....  1693210805
# 42  {'latitude': '-16.069034', 'longitude': '-117....  1693210805
# 43  {'latitude': '-77.894360', 'longitude': '117.0...  1693210806
# 45  {'latitude': '-24.407903', 'longitude': '-105....  1693210807
# 48  {'latitude': '24.7229325', 'longitude': '1.524...  1693210809

# %%
df_dictionary['location_lead'] = df_dictionary.groupby(['device_id'])['location'].shift(-1).fillna(df_dictionary['location'])

# %%
df_dictionary.head(51)
# Out:
#                                device_id  temperature  \
# 0   5390df32-b924-44e9-b416-eb31066741e4           34
# 1   5390df32-b924-44e9-b416-eb31066741e4           23
# 5   5390df32-b924-44e9-b416-eb31066741e4           33
# 7   5390df32-b924-44e9-b416-eb31066741e4           24
# 9   5390df32-b924-44e9-b416-eb31066741e4           10
# 10  5390df32-b924-44e9-b416-eb31066741e4           31
# 14  5390df32-b924-44e9-b416-eb31066741e4           45
# 18  5390df32-b924-44e9-b416-eb31066741e4           19
# 20  5390df32-b924-44e9-b416-eb31066741e4           14
# 22  5390df32-b924-44e9-b416-eb31066741e4           20
# 24  5390df32-b924-44e9-b416-eb31066741e4           23
# 25  5390df32-b924-44e9-b416-eb31066741e4           44
# 27  5390df32-b924-44e9-b416-eb31066741e4           50
# 28  5390df32-b924-44e9-b416-eb31066741e4           12
# 29  5390df32-b924-44e9-b416-eb31066741e4           50
# 31  5390df32-b924-44e9-b416-eb31066741e4           14
# 34  5390df32-b924-44e9-b416-eb31066741e4           21
# 10  {'latitude': '-16.852542', 'longitude': '-67.3...
# 14  {'latitude': '29.0324935', 'longitude': '-2.42...
# 18  {'latitude': '-57.420107', 'longitude': '-153....
# 20  {'latitude': '-31.888895', 'longitude': '161.2...
# 22  {'latitude': '-31.3529895', 'longitude': '119....
# 24  {'latitude': '57.3829665', 'longitude': '-132....
# 25  {'latitude': '72.909677', 'longitude': '57.327...
# 27  {'latitude': '-62.699463', 'longitude': '64.35...
# 28  {'latitude': '-66.845788', 'longitude': '54.32...
# 29  {'latitude': '-57.0459655', 'longitude': '-123...
# 31  {'latitude': '19.433276', 'longitude': '-147.9...
# 34  {'latitude': '69.4076325', 'longitude': '-163....
# 35  {'latitude': '-71.778121', 'longitude': '7.921...
# 36  {'latitude': '77.6817705', 'longitude': '64.74...
# 40  {'latitude': '-73.246493', 'longitude': '-55.9...
# 44  {'latitude': '-72.147558', 'longitude': '-161....
# 46  {'latitude': '-80.7920305', 'longitude': '83.9...
# 47  {'latitude': '34.5427425', 'longitude': '-5.20...
# 49  {'latitude': '34.5427425', 'longitude': '-5.20...
# 2   {'latitude': '64.1164715', 'longitude': '-10.3...
# 3   {'latitude': '73.8800505', 'longitude': '-104....
# 4   {'latitude': '68.502382', 'longitude': '177.70...
# 6   {'latitude': '-57.2823875', 'longitude': '41.5...
# 8   {'latitude': '-32.904390', 'longitude': '115.9...
# 11  {'latitude': '8.3313785', 'longitude': '-175.9...
# 12  {'latitude': '73.693304', 'longitude': '-1.058...
# 13  {'latitude': '23.3508845', 'longitude': '-25.3...
# 15  {'latitude': '-15.112969', 'longitude': '-22.1...
# 16  {'latitude': '29.956552', 'longitude': '98.060...
# 17  {'latitude': '57.2631085', 'longitude': '-54.1...
# 19  {'latitude': '-26.652955', 'longitude': '-119....
# 21  {'latitude': '68.9954395', 'longitude': '-87.2...
# 23  {'latitude': '70.8020285', 'longitude': '-22.9...
# 26  {'latitude': '5.7248575', 'longitude': '-62.41...
# 30  {'latitude': '29.1181555', 'longitude': '-2.58...
# 32  {'latitude': '72.0302635', 'longitude': '-45.1...
# 33  {'latitude': '-28.8357565', 'longitude': '95.9...
# 37  {'latitude': '26.727525', 'longitude': '135.53...
# 38  {'latitude': '-9.6067815', 'longitude': '130.4...
# 39  {'latitude': '-26.7759195', 'longitude': '-71....
# 41  {'latitude': '-16.069034', 'longitude': '-117....
# 42  {'latitude': '-77.894360', 'longitude': '117.0...
# 43  {'latitude': '-24.407903', 'longitude': '-105....
# 45  {'latitude': '24.7229325', 'longitude': '1.524...
# 48  {'latitude': '24.7229325', 'longitude': '1.524...

# %%
def calculate_distance(location1, location2):
    location1=(float(location1['latitude']),float(location1['longitude']))
    location2=(float(location2['latitude']),float(location2['longitude']))
    miles = distance.distance(location1, location2).miles
    return miles

# %%
df_dictionary['distance'] = df_dictionary.apply(lambda x: calculate_distance(x.location, x.location_lead), axis=1)

# %% [markdown]
# # Tasks
#
# a. The maximum temperatures measured for every device per hours.
#
# b. The amount of data points aggregated for every device per hours.
#
# c. Total distance of device movement for every device per hours.

# %%
transformed_data = df_dictionary.groupby('device_id').agg(
                        {'temperature':'max',
                         'time':['count','max'],
                         'distance':'sum'}).reset_index()

# %%
transformed_data.head()
# Out:
#                               device_id temperature  time              \
#                                                 max count         max
# 0  5390df32-b924-44e9-b416-eb31066741e4          50    24  1693210809
# 1  f87141eb-feff-45b8-88a4-0550d58a14ac          50    26  1693210809
#
#         distance
#              sum
# 0  130769.171312
# 1  136411.813106

# %%
transformed_data.columns = ['device_id','max_temperature','count_data_points','extract_dt','total_distance_km']

# %%
transformed_data['extract_dt'] = transformed_data['extract_dt'].apply(lambda x: datetime.utcfromtimestamp(int(x)).strftime('%Y-%m-%d %H:%M:%S'))

# %%
transformed_data
# Out:
#                               device_id  max_temperature  count_data_points  \
# 0  5390df32-b924-44e9-b416-eb31066741e4               50                 24
# 1  f87141eb-feff-45b8-88a4-0550d58a14ac               50                 26
#
#             extract_dt  total_distance_km
# 0  2023-08-28 08:20:09      130769.171312
# 1  2023-08-28 08:20:09      136411.813106

# %% [markdown]
# # Test SQL Engines

# %%
transformed_data.to_sql('devices_agg_data', mysql_engine,if_exists='append', index = False)
# Out:
# 2

# %%
EXTRACT_DATA_LAST_HOUR_QUERY = """
      select device_id,temperature,location,to_timestamp(time::int) as event_dt
      from devices
      where to_timestamp(time::int) between '{current_timestamp}'::timestamp - interval '59 minutes 59 seconds'
              and '{current_timestamp}'::timestamp order by time
      """

# %%
from sqlalchemy import create_engine, Table, Column, Integer, String, MetaData, BigInteger, DateTime
from sqlalchemy.exc import OperationalError
from datetime import datetime

# %%
mysql_engine = create_engine('mysql+pymysql://nonroot:nonroot@localhost/analytics?charset=utf8', pool_pre_ping=True, pool_size=10)

# %%
psql_engine = create_engine('postgresql+psycopg2://postgres:password@localhost:5432/main', pool_pre_ping=True, pool_size=10)

# %%
extracted_data = pd.read_sql(EXTRACT_DATA_LAST_HOUR_QUERY,psql_engine)
print(extracted_data.shape)

# %%
extracted_data.head()
# Out:
#                               device_id  temperature  \
# 0  9ea0877d-d680-43c5-b1a3-5ac7c08e351e           24
# 1  46ba5134-dd09-415e-aaaf-fe5f90231135           32
# 2  25aa87b8-56ed-41f9-b955-706f3bf0f69b           38
# 3  9ea0877d-d680-43c5-b1a3-5ac7c08e351e           34
# 4  46ba5134-dd09-415e-aaaf-fe5f90231135           50
#
#                                             location        time
# 0  {"latitude": "-70.598631", "longitude": "-4.41...  1693207674
# 1  {"latitude": "-43.4104115", "longitude": "174....  1693207674
# 2  {"latitude": "-60.739830", "longitude": "1.671...  1693207674
# 3  {"latitude": "-5.123777", "longitude": "25.234...  1693207675
# 4  {"latitude": "44.061240", "longitude": "50.889...  1693207675
